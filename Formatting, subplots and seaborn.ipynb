# %%
import seaborn
import pandas
import matplotlib.pyplot as plt
import numpy

# %matplotlib inline

# %%
workouts = pandas.read_csv('workouts_clean.csv')

# %%
workouts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 29 columns):
# Date_Submitted                 323 non-null object
# Workout_Date                   323 non-null object
# Month                          323 non-null float64
# Distance                       323 non-null float64
# Workout_Time                   323 non-null float64
# Workout_Time_min               323 non-null float64
# Year                           325 non-null object
# Activity Type                  325 non-null object
# Calories Burned (kCal)         324 non-null object
# Adjusted Distance CAL          324 non-null object
# Adjusted Distance TIME         323 non-null float64
# Difference from Actual CAL     324 non-null object
# Difference from Actual TIME    323 non-null object
# Calories per Mile              323 non-null float64
# Seconds per Mile               323 non-null float64
# Avg Pace (min/mi)              323 non-null float64
# ...

# %%
workouts['Workout_Date'] = pandas.to_datetime(workouts['Workout_Date'])

# %%
workouts = workouts[:-6]

# %%
workouts
# Out:
#     Date_Submitted Workout_Date  Month   Distance  Workout_Time  \
# 0          3/14/17   2017-03-14    3.0   1.415430      518.0000
# 1          7/23/17   2017-07-23    7.0   1.291830      481.0000
# 2          9/29/16   2016-09-29    9.0   2.530000     1500.0000
# 3          3/19/17   2017-03-19    3.0   3.651810     1427.0000
# 4          11/9/16   2016-11-09   11.0   2.500000     1575.0000
# 5          8/28/17   2017-08-28    8.0   2.539140     1023.0000
# 6         11/22/16   2016-11-22   11.0   1.275930      532.0000
# 7         10/23/16   2016-10-23   10.0   2.510210     1051.0000
# 8          9/16/16   2016-09-16    9.0   2.514330     1062.0000
# 9          9/30/16   2016-09-30    9.0   2.512130     1073.0000
# 10         3/10/17   2017-03-10    3.0   1.194600      511.0000
# 11         10/1/16   2016-10-01   10.0   2.566290     1098.0000
# 12         11/3/16   2016-11-03   11.0   1.953080      837.0000
# 13         9/25/16   2016-09-25    9.0   2.385910     1023.0000
# ...

# %%
# Minute per mile variable

workouts['mpm'] = workouts['Workout_Time'] / 60 / workouts['Distance']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
workouts['mpm']
# Out:
# 0       6.099442
# 1       6.205667
# 2       9.881423
# 3       6.512752
# 4      10.500000
# 5       6.714872
# 6       6.949180
# 7       6.978168
# 8       7.039649
# 9       7.118793
# 10      7.129304
# 11      7.130917
# 12      7.142565
# 13      7.146120
# 14      7.196251
# 15      7.208352
# 16      7.229592
# 17      7.233767
# 18      7.246767
# 19      7.260872
# 20      7.270406
# 21      7.278860
# 22      7.313189
# 23      7.332979
# 24      7.344965
# 25      7.350470
# 26      7.345662
# 27      7.357666
# 28      7.357549
# 29      7.365662
#          ...
# 293     9.652605
# 294     9.671160
# 295     9.714836
# 296     9.719664
# 297     9.811665
# 298     9.813811
# 299     9.826915
# 300     9.890411
# 301     9.925423
# 302     9.984390
# 303    10.009548
# 304    10.039288
# 305    10.152185
# 306    10.212640
# 307    10.263899
# 308    10.266737
# 309    10.287466
# 310    10.874046
# 311    11.308797
# 312    11.425904
# 313    11.439722
# ...

# %%
plt.hist(workouts['Distance'])
plt.show()

# %%
plt.plot(workouts.iloc[:]['Distance'])

# %%
norm = numpy.random.normal(0, 1, workouts['Distance'].count())
norm.sort()
plt.plot(norm, workouts['Distance'].sort_values(), "o")
plt.show()
