# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data = pd.DataFrame()
data['gender'] = ['male'] * 100 + ['female'] * 100
data['height'] = np.append(np.random.normal(69, 15, 100), np.random.normal(64, 12, 100))
data['weight'] = np.append(np.random.normal(195, 25, 100), np.random.normal(165, 15, 100))

# %%
data.head()
# Out:
#   gender      height      weight
# 0   male  108.886999  150.792260
# 1   male   78.722266  229.686948
# 2   male   86.581866  198.700042
# 3   male   61.317323  158.026347
# 4   male   59.434371  204.097866

# %%
data.head(200)
# Out:
#      gender      height      weight
# 0      male  108.886999  150.792260
# 1      male   78.722266  229.686948
# 2      male   86.581866  198.700042
# 3      male   61.317323  158.026347
# 4      male   59.434371  204.097866
# 5      male   80.695190  228.428047
# 6      male   76.480515  162.779615
# 7      male   41.545033  188.695758
# 8      male   80.916900  207.677513
# 9      male   68.836602  192.380300
# 10     male   86.082771  154.252143
# 11     male   83.818243  251.551291
# 12     male   72.265125  141.694159
# 13     male   63.901888  178.417676
# 14     male   41.092096  173.406822
# 15     male   89.985471  137.608205
# 16     male   89.959643  180.417440
# 17     male   69.475461  228.296668
# 18     male   38.681107  176.943480
# 19     male   58.330745  221.704418
# 20     male   62.571731  182.698899
# 21     male   53.707321  198.325196
# 22     male   88.993889  167.149706
# 23     male   76.275548  175.979964
# 24     male   65.530683  190.845421
# ...

# %%
bradybunch = pd.DataFrame()

# %%
bradybunch['names'] = ['Greg', 'Marcia', 'Peter', 'Jan', 'Bobby', 'Cousin Oliver', 'Cindy']
bradybunch['ages'] = [14 , 12, 11, 10, 8, 8, 6]

# %%
bradybunch.describe()
# Out:
#             ages
# count   7.000000
# mean    9.857143
# std     2.734262
# min     6.000000
# 25%     8.000000
# 50%    10.000000
# 75%    11.500000
# max    14.000000

# %%
std_error = bradybunch.std()/(7 ** 0.5)

# %%
print(std_error)
# Out:
# ages    1.033454
# dtype: float64

# %%
bradybunch.at[6,'ages'] += 1

# %%
bradybunch
# Out:
#            names  ages
# 0           Greg    14
# 1         Marcia    12
# 2          Peter    11
# 3            Jan    10
# 4          Bobby     8
# 5  Cousin Oliver     8
# 6          Cindy     7

# %%
bradybunch.describe()
# Out:
#             ages
# count   7.000000
# mean   10.000000
# std     2.516611
# min     7.000000
# 25%     8.000000
# 50%    10.000000
# 75%    11.500000
# max    14.000000

# %%
bradybunch.at[5,'ages'] = 1
bradybunch.at[5, 'names'] = 'Jessica'

# %%
bradybunch.describe()
# Out:
#             ages
# count   7.000000
# mean    9.000000
# std     4.242641
# min     1.000000
# 25%     7.500000
# 50%    10.000000
# 75%    11.500000
# max    14.000000

# %%
bradybunch
# Out:
#      names  ages
# 0     Greg    14
# 1   Marcia    12
# 2    Peter    11
# 3      Jan    10
# 4    Bobby     8
# 5  Jessica     1
# 6    Cindy     7
